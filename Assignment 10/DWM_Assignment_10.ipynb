# %% [markdown]
# <h2>Name: Abhishek Wekhande</h2>
# <h2>PRN: 22070521113</h2>

# %%
# !pip install pandas matplotlib scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load dataset
df = pd.read_csv('/content/IRIS.csv')  # Make sure to download the dataset (link below)

# Use only the numerical features (remove label)
X = df.iloc[:, :-1]

# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)

# Add the cluster labels to the dataframe
df['Cluster'] = kmeans.labels_

# Visualize clusters (using first two features)
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.show()
